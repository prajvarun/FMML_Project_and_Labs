# %% [markdown]
# <a href="https://colab.research.google.com/github/prajvarun/FMML_Project_and_Labs/blob/main/module_8_lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-04-26 17:55:11--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   162MB/s    in 0.4s
#
# 2024-04-26 17:55:12 (162 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 18063  cs/0211040v1  This paper proposes a model for combination of...    cs
# 16196  1610.07418v1  This paper discusses Centre for Development of...    cs
# 14635  cs/0611113v1  MontyLingua, an integral part of ConceptNet wh...    cs
# 33516   1405.6285v1  The past decade has seen the rapid development...    cs
# 16864  1706.09562v1  We study how different frame annotations compl...    cs
# ...             ...                                                ...   ...
# 21618   1201.6082v1  In many situations where the interest lies in ...  stat
# 2839   1802.06476v1  Type 2 diabetes mellitus (T2DM) is a chronic d...    cs
# 33341   1208.0318v1  This paper investigates typical behaviors like...    cs
# 30662  1712.09775v2  This report presents the results of a sky dete...    cs
# 3124    0810.4401v2  We give polynomial-time algorithms for the exa...    cs
#
#                                                    title  year  \
# 18063  A Model for Combination of External and Intern...  2002
# 16196  Statistical Machine Translation for Indian Lan...  2016
# 14635  An Anthological Review of Research Utilizing M...  2006
# 33516  Traversing News with Ant Colony Optimisation a...  2014
# 16864  Frame-Based Continuous Lexical Semantics throu...  2017
# ...                                                  ...   ...
# 21618   A robust and sparse K-means clustering algorithm  2012
# 2839   Simultaneous Modeling of Multiple Complication...  2018
# 33341  Artificial Neural Network Based Prediction of ...  2012
# 30662  Sky detection and log illumination refinement ...  2017
# 3124    Efficient Exact Inference in Planar Ising Models  2008
#
#                                                 keywords
# 18063  [combination, selection, autonomous, selection...
# 16196  [discusses, development, computing, submission...
# 14635  [montylingua, conceptnet, currently, commonsen...
# 33516  [development, published, surpassing, tradition...
# 16864  [different, annotations, complement, continuou...
# ...                                                  ...
# 21618  [situations, identifying, available, variables...
# 2839   [complications, prediction, profiling, complic...
# 33341  [investigates, behaviors, oscillations, fracti...
# 30662  [detection, technique, performance, previously...
# 3124   [polynomial, algorithms, computation, violator...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 18063    [combination, selection, autonomous, selection...
# 16196    [discusses, development, computing, submission...
# 14635    [montylingua, conceptnet, currently, commonsen...
# 33516    [development, published, surpassing, tradition...
# 16864    [different, annotations, complement, continuou...
#                                ...
# 30442    [reflections, reflectors, performance, algorit...
# 21442    [construct, truncated, specifically, algorithm...
# 40916    [introduced, guaranteed, resources, management...
# 29823    [anticipating, intention, observing, applicati...
# 18384    [currently, criminals, investigators, psycholo...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8743 words.
# Out of those 4567 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="5af495be-46e1-4152-9e49-9d145b0c08f6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5af495be-46e1-4152-9e49-9d145b0c08f6")) {                    Plotly.newPlot(                        "5af495be-46e1-4152-9e49-9d145b0c08f6",                        [{"x":["combination","behaviour","autonomous","selection","mechanism","previously","multiplicative","incorporate","parameter","properties","dependence","statistical","languages","separation","outperforms","objective","computing","translation","effectiveness","significantly","reordering","splitting","discusses","agglutinative","submission","development","substituted","information","component","components","conceptnet","exploring","currently","developed","different","independently","optimistic","individual","knowledge","published","processing","architectural","commonsense","diversified","processor","programming","utilizing","summarizing","generation","newspapers","presented","challenges","consumption","traversing","available","surpassing","documents","algorithm","intelligence","optimisation","traditional","pheromones","understand","hamiltonian","production","important","newspaper","pheromone","baselines","factorization","semantics","representations","exponential","consistently","syntactic","continuous","complement","annotations","essential","healthcare","efficiency","structures","operation","applicability","applications","sequences","analyzing","quantitative","collections","subsumption","meaningful","mathematical","reduction","sequential","heterogeneous","interesting","framework","discovering","extension","motivation","enumerate","projections","qualitative","marketing","particular","literature","scenarios","introduce","computations","therefore","additionally","satisfiability","operators","decidable","distinguished","interaction","illustrate","resulting","machinery","equivalence","corresponds","preserves","involving","respectively","consequence","epistemic","expressive","parameters","monocular","experimentally","factoring","intrinsic","localization","trajectory","asynchronous","detection","calibration","nonlinear","validated","initialize","informative","automatic","optimization","estimates","simultaneous","probability","significant","technique","calibrate","likelihood","featuring","demonstrated","observability","correlation","theoretic","submodular","leveraging","inference","simulated","dimensional","highlight","constraints","classical","proposing","introduced","expressed","enumeration","principal","efficient","structure","established","canonical","guarantees","probabilistic","algorithms","projection","approximate","regression","applicable","neuroimaging","structured","empirical","combinatorial","performance","variables","manuscript","topological","perspective","advancement","approaching","investigate","assumptions","distribution","obstructive","classifying","tomography","propagated","averaging","instances","quantification"],"y":[134,38,59,161,101,86,12,55,125,213,29,170,98,24,239,154,121,111,198,261,5,8,39,3,4,120,2,703,108,91,4,49,60,189,785,48,9,114,343,39,296,17,7,4,8,115,40,9,139,3,190,107,28,2,290,8,70,801,95,14,175,2,83,5,21,358,2,2,57,34,93,228,43,38,43,120,22,88,59,11,152,135,36,38,407,111,78,64,21,5,51,53,91,67,40,70,531,40,79,23,5,24,57,6,276,113,94,360,32,134,73,26,51,5,14,88,67,156,5,23,25,15,47,100,20,9,40,233,18,70,5,50,67,24,11,335,25,50,34,9,36,180,325,72,22,164,233,243,1,68,3,91,6,70,51,15,33,191,66,188,39,140,109,22,134,39,2,31,402,359,45,15,62,172,599,41,105,123,49,4,104,134,40,882,132,4,25,71,4,5,137,55,195,1,40,16,8,17,97,17],"type":"bar"},{"x":["combination","behaviour","autonomous","selection","mechanism","previously","multiplicative","incorporate","para ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4567,), (4567, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8183333333333334

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>BIRDNEST</span> <span style=''>Bayesian</span> <span style='background-color:rgba(255, 0, 0, 0.3536379018612521);'>Inference</span> <span style=''>for</span> <span style=''>Ratings</span> <span style=''>Fraud</span> <span style='background-color:rgba(0, 255, 0, 0.5296803652968036);'>Detection</span> <br/><br/><span style=''>Review</span> <span style=''>fraud</span> <span style=''>is</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.7142857142857143);'>pervasive</span> <span style=''>problem</span> <span style=''>in</span> <span style=''>online</span> <span style=''>commerce</span> <span style=''>in</span> <span style=''>which</span> <span style=''>fraudulent</span> <span style=''>sellers</span> <span style=''>write</span> <span style=''>or</span> <span style=''>purchase</span> <span style=''>fake</span> <span style=''>reviews</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.6000000000000001);'>manipulate</span> <span style='background-color:rgba(0, 255, 0, 0.746031746031746);'>perception</span> <span style=''>of</span> <span style=''>their</span> <span style=''>products</span> <span style=''>and</span> <span style=''>services</span> <span style=''>Fake</span> <span style=''>reviews</span> <span style=''>are</span> <span style=''>often</span> <span style=''>detected</span> <span style=''>based</span> <span style=''>on</span> <span style=''>several</span> <span style=''>signs</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>including</span> <span style=''>1)</span> <span style=''>they</span> <span style=''>occur</span> <span style=''>in</span> <span style=''>short</span> <span style=''>bursts</span> <span style=''>of</span> <span style=''>time</span> <span style=''>2)</span> <span style=''>fraudulent</span> <span style=''>user</span> <span style=''>accounts</span> <span style=''>have</span> <span style=''>skewed</span> <span style=''>rating</span> <span style='background-color:rgba(255, 0, 0, 0.32110091743119257);'>distributions</span> <span style=''>However</span> <span style=''>these</span> <span style=''>may</span> <span style=''>both</span> <span style=''>be</span> <span style=''>true</span> <span style=''>in</span> <span style=''>any</span> <span style=''>given</span> <span style=''>dataset</span> <span style=''>Hence</span> <span style=''>in</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>an</span> <span style=''>approach</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.4912280701754386);'>detecting</span> <span style=''>fraudulent</span> <span style=''>reviews</span> <span style=''>which</span> <span style=''>combines</span> <span style=''>these</span> <span style=''>2</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approaches</span> <span style=''>in</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3150684931506849);'>principled</span> <span style=''>manner</span> <span style=''>allowing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>successful</span> <span style='background-color:rgba(0, 255, 0, 0.5296803652968036);'>detection</span> <span style=''>even</span> <span style=''>when</span> <span style=''>one</span> <span style=''>of</span> <span style=''>these</span> <span style=''>signs</span> <span style=''>is</span> <span style=''>not</span> <span style=''>present</span> <span style=''>To</span> <span style=''>combine</span> <span style=''>these</span> <span style=''>2</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approaches</span> <span style=''>we</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>formulate</span> <span style=''>our</span> <span style=''>Bayesian</span> <span style='background-color:rgba(255, 0, 0, 0.3536379018612521);'>Inference</span> <span style=''>for</span> <span style=''>Rating</span> <span style=''>Data</span> <span sty ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Mixed</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>membership</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stochastic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>blockmodels</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3);'>Observations</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>consisting</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>measurements</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>relationships</span> <span style=''>for</span> <span style=''>pairs</span> <span style=''>of</span> <span style=''>objects</span> <span style=''>arise</span> <span style=''>in</span> <span style=''>many</span> <span style=''>settings</span> <span style=''>such</span> <span style=''>as</span> <span style=''>protein</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interaction</span> <span style=''>and</span> <span style=''>gene</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>regulatory</span> <span style=''>networks</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>collections</span> <span style=''>of</span> <span style=''>author</span> <span style=''>recipient</span> <span style=''>email</span> <span style=''>and</span> <span style=''>social</span> <span style=''>networks</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Analyzing</span> <span style=''>such</span> <span style=''>data</span> <span style=''>with</span> <span style=''>probabilisic</span> <span style=''>models</span> <span style=''>can</span> <span style=''>be</span> <span style=''>delicate</span> <span style=''>because</span> <span style=''>the</span> <span style=''>simple</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>exchangeability</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>assumptions</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>underlying</span> <span style=''>many</span> <span style=''>boilerplate</span> <span style=''>models</span> <span style=''>no</span> <span style=''>longer</span> <span style=''>hold</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>describe</span> <span style=''>a</span> <span style=''>latent</span> <span style=''>variable</span> <span style=''>model</span> <span style=''>of</span> <span style=''>such</span> <span style=''>data</span> <span style=''>called</span> <span style=''>the</span> <span style=''>mixed</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>membership</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stochastic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>blockmodel</span> <span style=''>This</span> <span style=''>model</span> <span style=''>extends</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>blockmodels</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>relational</span> <span style=''>data</span> <span style=''>to</span> <span style=''>ones</span> <span style=''>which</span> <span style=''>capture</span> <span style=''>mixed</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>membership</span> <span style=''>latent</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>relational</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structure</span> <span style=''>thus</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>providing</span> <span style=''>an</span> <span style=''>object</span> <span style=''>specific</span> <span style=''>low</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representation</span> <span style=''>We</span> <span style=''>develop</span> <span style=''>a</span> <span style=''>general</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variational</span> <span style='ba ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Interpretation</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Generalization</span> <span style=''>of</span> <span style=''>Score</span> <span style=''>Matching</span> <br/><br/><span style=''>Score</span> <span style=''>matching</span> <span style=''>is</span> <span style=''>a</span> <span style=''>recently</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>developed</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameter</span> <span style=''>learning</span> <span style=''>method</span> <span style=''>that</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>particularly</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>effective</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>complicated</span> <span style=''>high</span> <span style='background-color:rgba(255, 0, 0, 0.3151183970856102);'>dimensional</span> <span style=''>density</span> <span style=''>models</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.4754098360655737);'>intractable</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>partition</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>functions</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>study</span> <span style=''>two</span> <span style=''>issues</span> <span style=''>that</span> <span style=''>have</span> <span style=''>not</span> <span style=''>been</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>completely</span> <span style=''>resolved</span> <span style=''>for</span> <span style=''>score</span> <span style=''>matching</span> <span style=''>First</span> <span style=''>we</span> <span style=''>provide</span> <span style=''>a</span> <span style=''>formal</span> <span style=''>link</span> <span style=''>between</span> <span style=''>maximum</span> <span style='background-color:rgba(255, 0, 0, 0.4749034749034749);'>likelihood</span> <span style=''>and</span> <span style=''>score</span> <span style=''>matching</span> <span style=''>Our</span> <span style=''>analysis</span> <span style=''>shows</span> <span style=''>that</span> <span style=''>score</span> <span style=''>matching</span> <span style=''>finds</span> <span style=''>model</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameters</span> <span style=''>that</span> <span style=''>are</span> <span style=''>more</span> <span style=''>robust</span> <span style=''>with</span> <span style=''>noisy</span> <span style=''>training</span> <span style=''>data</span> <span style=''>Second</span> <span style=''>we</span> <span style=''>develop</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generalization</span> <span style=''>of</span> <span style=''>score</span> <span style=''>matching</span> <span style=''>Based</span> <span style=''>on</span> <span style=''>this</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generalization</span> <span style=''>we</span> <span style=''>further</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>demonstrate</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>extension</span> <span style=''>of</span> <span style=''>score</span> <span style=''>matching</span> <span style=''>to</span> <span style=''>models</span> <span style=''>of</span> <span style=''>discrete</span> <span style=''>data</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style=''>Bayesian</span> <span style=''>Method</span> <span style=''>for</span> <span style=''>Joint</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Clustering</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Vectorial</span> <span style=''>Data</span> <span style=''>and</span> <span style=''>Network</span> <span style=''>Data</span> <br/><br/><span style=''>We</span> <span style=''>present</span> <span style=''>a</span> <span style=''>new</span> <span style=''>model</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>integrative</span> <span style=''>method</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style=''>objects</span> <span style=''>given</span> <span style=''>both</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>vectorial</span> <span style=''>data</span> <span style=''>which</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>describes</span> <span style=''>the</span> <span style=''>feature</span> <span style=''>of</span> <span style=''>each</span> <span style=''>object</span> <span style=''>and</span> <span style=''>network</span> <span style=''>data</span> <span style=''>which</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>indicates</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>similarity</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>connected</span> <span style=''>objects</span> <span style=''>The</span> <span style=''>proposed</span> <span style=''>general</span> <span style=''>model</span> <span style=''>is</span> <span style=''>able</span> <span style=''>to</span> <span style=''>cluster</span> <span style=''>the</span> <span style=''>two</span> <span style=''>types</span> <span style=''>of</span> <span style=''>data</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>simultaneously</span> <span style=''>within</span> <span style=''>one</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>integrative</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabilistic</span> <span style=''>model</span> <span style=''>while</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>traditional</span> <span style=''>methods</span> <span style=''>can</span> <span style=''>only</span> <span style=''>handle</span> <span style=''>one</span> <span style=''>data</span> <span style=''>type</span> <span style=''>or</span> <span style=''>depend</span> <span style=''>on</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>transforming</span> <span style=''>one</span> <span style=''>data</span> <span style=''>type</span> <span style=''>to</span> <span style=''>another</span> <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conducted</span> <span style=''>based</span> <span style=''>on</span> <span style=''>a</span> <span style=''>Markov</span> <span style=''>chain</span> <span style=''>Monte</span> <span style=''>Carlo</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>A</span> <span style=''>special</span> <span style=''>case</span> <span style=''>of</span> <span style=''>the</span> <span style=''>general</span> <span style=''>model</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>combining</span> <span style=''>the</span> <span style=''>Gaussian</span> <span style=''>mixture</span> <span style=''>model</span> <span style=''>and</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stochastic</span> <span style=''>block</span> <span style=''>model</span> <span style=''>is</span> <sp ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	reasoning (0.05529789511237959)
# 	segmentation (0.06992508027113807)
# 	evaluation (0.09775240813414199)
# 	processing (0.10560114163396361)
# 	architecture (0.08704958972529432)
# 	information (0.25080271138066357)
# 	detection (0.11951480556546558)
# 	convolutional (0.12129860863360685)
# 	recognition (0.13592579379236533)
# 	different (0.2800570816981805)
#
# Some Statistics words are:
# 	stochastic (0.12919379068602904)
# 	theoretical (0.14872308462694042)
# 	variables (0.13770655983975963)
# 	statistical (0.15523284927391087)
# 	algorithm (0.3915873810716074)
# 	estimation (0.1757636454682023)
# 	dimensional (0.18077115673510266)
# 	distribution (0.19128693039559339)
# 	inference (0.200300450676014)
# 	regression (0.18027040560841262)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="82115b87-a210-4ac6-a764-fda0b627d2c8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("82115b87-a210-4ac6-a764-fda0b627d2c8")) {                    Plotly.newPlot(                        "82115b87-a210-4ac6-a764-fda0b627d2c8",                        [{"x":["combination","behaviour","autonomous","selection","mechanism","previously","multiplicative","incorporate","parameter","properties","dependence","statistical","languages","separation","outperforms","objective","computing","translation","effectiveness","significantly","reordering","splitting","discusses","agglutinative","submission","development","substituted","information","component","components","conceptnet","exploring","currently","developed","different","independently","optimistic","individual","knowledge","published","processing","architectural","commonsense","diversified","processor","programming","utilizing","summarizing","generation","newspapers","presented","challenges","consumption","traversing","available","surpassing","documents","algorithm","intelligence","optimisation","traditional","pheromones","understand","hamiltonian","production","important","newspaper","pheromone","baselines","factorization","semantics","representations","exponential","consistently","syntactic","continuous","complement","annotations","essential","healthcare","efficiency","structures","operation","applicability","applications","sequences","analyzing","quantitative","collections","subsumption","meaningful","mathematical","reduction","sequential","heterogeneous","interesting","framework","discovering","extension","motivation","enumerate","projections","qualitative","marketing","particular","literature","scenarios","introduce","computations","therefore","additionally","satisfiability","operators","decidable","distinguished","interaction","illustrate","resulting","machinery","equivalence","corresponds","preserves","involving","respectively","consequence","epistemic","expressive","parameters","monocular","experimentally","factoring","intrinsic","localization","trajectory","asynchronous","detection","calibration","nonlinear","validated","initialize","informative","automatic","optimization","estimates","simultaneous","probability","significant","technique","calibrate","likelihood","featuring","demonstrated","observability","correlation","theoretic","submodular","leveraging","inference","simulated","dimensional","highlight","constraints","classical","proposing","introduced","expressed","enumeration","principal","efficient","structure","established","canonical","guarantees","probabilistic","algorithms","projection","approximate","regression","applicable","neuroimaging","structured","empirical","combinatorial","performance","variables","manuscript","topological","perspective","advancement","approaching","investigate","assumptions","distribution","obstructive","classifying","tomography","propagated","averaging","instances","quantification","pulmonary","quantified","combining","classification","increases","considering","diagnosis","incorrectly","variational","construct","additional","observation","dimensionality","straightforward","embedding","observations","intuitions","preserving","relationships","extensions","discovery","posterior","neighbourhood","conditioned","describes","hypothesised","coordinates","understanding","implementation","procedures","collecting","parametrisation","equations","references","processes","derivations","implemented","derivation","accompany","appropriate","substantial","secondary","morphological","equivalent","architecture","addresses","translating","decomposition","linguistic","vocabulary","experiments","performed","representation","improvement","attention","grammati ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	semiparametric
# 	detailing
# 	transports
# 	repulsive
# 	practicing
# 	bootstrapped
# 	distributionally
# 	certifiable
# 	supercomputers
# 	unmodified
# 	minibatch
# 	tremendously
# 	reassignment
# 	multipartite
# 	broadening
# 	sparsistent
# 	distinguishability
# 	straggler
# 	unobservable
# 	econometrics
# Some words which never appear in Statistics papers:
# 	reordering
# 	agglutinative
# 	substituted
# 	conceptnet
# 	commonsense
# 	newspapers
# 	surpassing
# 	pheromones
# 	newspaper
# 	pheromone
# 	syntactic
# 	subsumption
# 	satisfiability
# 	decidable
# 	monocular
# 	featuring
# 	semantical
# 	delineating
# 	displacement
# 	panchromatic

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.067766972420775e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7591666666666667
